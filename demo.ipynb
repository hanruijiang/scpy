# %% [markdown]
# # Scpy, a single-cell gene differential expression analysis tool based on pytorch

# %% [markdown]
# We use the data of Gasperini et al. [1] as an example to show how to use scpy for differential expression analysis, and compare it with the R package monocle3 [2,3].
#
# Gasperini et al. performed CRISPRi screening in the K562 cell line. In the at-scale experiment, they transfected 6,542 gRNA groups, and measured their effect on 13,135 highly expressed genes in 207,324 cells with single-cell RNA-seq.
#
# We downloaded the expression matrix, gRNA list and phenotype data of the at-scale experiment from GEO (https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE120861).
#
# First, we execute the R workflow.

# %% [markdown]
# ## Monocle3

# %%
library(monocle3)
# Out:
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘monocle3’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     exprs, fData, fData<-, pData, pData<-

# %%
base <- '/home/jjpeng/data/yxlong/CRISPR/source/30849375/GEO/'

# %% [markdown]
# ### prepare featureData & phenoData

# %%
featureData <- read.table(gzfile(paste(base, 'GSE120861_at_scale_screen.genes.txt.gz', sep='')), row.names=1)
featureData['id'] <- row.names(featureData)

write.table(featureData, paste(base, 'at_scale.featureData.tsv', sep=''), sep='\t')

phenoData <- read.table(gzfile(paste(base, 'GSE120861_at_scale_screen.phenoData.txt.gz', sep='')), row.names=2)
phenoData <- phenoData[c(1:4, 6:10, 14, 17)]
colnames(phenoData) <- c('sample','total_umis','Size_Factor','gRNA_groups','barcodes','read_count','umi_count','proportion','guide_count','prep_batch','percent.mito')

write.table(phenoData, paste(base, 'at_scale.phenoData.tsv', sep=''), sep='\t')

# %% [markdown]
# ### load CellDataSet

# %%
cds <- monocle3::load_mm_data(
    mat_path = paste(base, 'GSE120861_at_scale_screen.exprs.mtx.gz', sep=''),
    feature_anno_path = paste(base, 'at_scale.featureData.tsv', sep=''),
    cell_anno_path = paste(base, 'at_scale.phenoData.tsv', sep=''),
    header=TRUE
)

cds
# Out:
# Warning message in new_cell_data_set(mat, cell_metadata = cell_annotations$metadata, :
# “Warning: gene_metadata must contain a column verbatim named 'gene_short_name' for certain functions.”
# class: cell_data_set
# dim: 13135 207324
# metadata(1): cds_version
# assays(1): counts
# rownames(13135): ENSG00000238009 ENSG00000237683 ... ENSG00000215615
#   ENSG00000215699
# rowData names(1): id
# colnames(207324): AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
#   AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2 ... TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9
#   TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# colData names(12): sample total_umis ... percent.mito n.umi
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %% [markdown]
# ### choose bassik_mch, a non-targeting control gRNA group and 100 genes as an example

# %%
genes = fData(cds)[1:100, 'id']

cds_subset <- cds[rowData(cds)$id %in% genes, ]

pData(cds_subset)['gRNA_group'] <- as.integer(lapply(pData(cds)[,'gRNA_groups'], function(x) grepl('bassik_mch', x)))

cds_subset
# Out:
# class: cell_data_set
# dim: 100 207324
# metadata(1): cds_version
# assays(1): counts
# rownames(100): ENSG00000238009 ENSG00000237683 ... ENSG00000116285
#   ENSG00000142599
# rowData names(1): id
# colnames(207324): AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
#   AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2 ... TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9
#   TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# colData names(13): sample total_umis ... n.umi gRNA_group
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %% [markdown]
# ### differential expression analysis

# %%
formula <- "~gRNA_group+guide_count+percent.mito+prep_batch"

tick <- Sys.time()
fits <- monocle3::fit_models(cds_subset, expression_family = 'negbinomial', model_formula_str = formula)
print(Sys.time() - tick)

coef <- coefficient_table(fits)[c('gene_id','status','term','estimate','std_err','test_val','p_value','normalized_effect','q_value')]

write.csv(coef, 'bassik_mch-100.csv', row.names=FALSE)

coef
# Out:
# Time difference of 4.225742 mins
#     gene_id         status term                   estimate      std_err
# 1   ENSG00000238009 OK     (Intercept)            -4.488624e+00 0.0588449363
# 2   ENSG00000238009 OK     gRNA_group              9.159409e-02 0.3206558563
# 3   ENSG00000238009 OK     guide_count            -4.850636e-04 0.0011927896
# 4   ENSG00000238009 OK     percent.mito            1.176492e+01 0.9931642069
# 5   ENSG00000238009 OK     prep_batchprep_batch_2  3.846924e-02 0.0358320781
# 6   ENSG00000237683 OK     (Intercept)            -3.598773e+00 0.0326945585
# 7   ENSG00000237683 OK     gRNA_group             -1.210731e-01 0.1899799610
# 8   ENSG00000237683 OK     guide_count             5.331953e-03 0.0006333395
# 9   ENSG00000237683 OK     percent.mito            1.494807e+01 0.5411345368
# 10  ENSG00000237683 OK     prep_batchprep_batch_2 -2.009985e-02 0.0195523402
# 11  ENSG00000228463 OK     (Intercept)            -5.546835e-01 0.0101808588
# 12  ENSG00000228463 OK     gRNA_group             -5.264484e-02 0.0619587382
# 13  ENSG00000228463 OK     guide_count            -1.015037e-03 0.0002140208
# 14  ENSG00000228463 OK     percent.mito            1.767073e+00 0.1800914084
# 15  ENSG00000228463 OK     prep_batchprep_batch_2  1.078760e-02 0.0064311246
# 16  ENSG00000237094 OK     (Intercept)            -3.933431e+00 0.0525286008
# 17  ENSG00000237094 OK     gRNA_group             -6.054079e-02 0.3206994621
# 18  ENSG00000237094 OK     guide_count            -3.168404e-03 0.0011039935
# 19  ENSG00000237094 OK     percent.mito            6.346012e+00 0.9138503874
# 20  ENSG00000237094 OK     prep_batchprep_batch_2 -2.497970e-02 0.0328591292
# 21  ENSG00000235373 OK     (Intercept)            -3.369559e+00 0.0357204679
# 22  ENSG00000235373 OK     gRNA_group             -1.471128e-01 0.2188461941
# 23  ENSG00000235373 OK     guide_count             2.161045e-03 0.0007257931
# 24  ENSG00000235373 OK     percent.mito            5.988558e+00 0.6159948836
# 25  ENSG00000235373 OK     prep_batchprep_batch_2  9.034320e-02 0.0220711187
# 26  ENSG00000228327 OK     (Intercept)            -4.438321e+00 0.0725558586
# 27  ENSG00000228327 OK     gRNA_group              3.016993e-01 0.3835027664
# 28  ENSG00000228327 OK     guide_count            -8.450155e-05 0.0015211272
# 29  ENSG00000228327 OK     percent.mito           -3.973746e+00 1.2968734491
# 30  ENSG00000228327 OK     prep_batchprep_batch_2  3.816423e-01 0.0460905071
# ⋮   ⋮               ⋮      ⋮                      ⋮             ⋮
# 471 ENSG00000049246 OK     (Intercept)            -1.785779e+00 1.539314e-02
# 472 ENSG00000049246 OK     gRNA_group             -7.872810e-04 8.860188e-02
# 473 ENSG00000049246 OK     guide_count             4.231625e-06 3.127432e-04
# 474 ENSG00000049246 OK     percent.mito            8.692280e+00 2.617372e-01
# 475 ENSG00000049246 OK     prep_batchprep_batch_2  1.576104e-01 9.420459e-03
# 476 ENSG00000236266 OK     (Intercept)            -4.826811e+00 6.612007e-02
# 477 ENSG00000236266 OK     gRNA_group             -1.722361e-01 4.054157e-01
# 478 ENSG00000236266 OK     guide_count            -1.507530e-03 1.333675e-03
# 479 ENSG00000236266 OK     percent.mito            1.523107e+01 1.101194e+00
# 480 ENSG00000236266 OK     prep_batchprep_batch_2  6.460213e-03 3.986820e-02
# 481 ENSG00000049249 OK     (Intercept)            -1.885403e+00 4.228033e-02
# 482 ENSG00000049249 OK     gRNA_group             -5.375649e-01 3.066142e-01
# 483 ENSG00000049249 OK     guide_count            -1.453363e-03 9.273117e-04
# 484 ENSG00000049249 OK     percent.mito           -3.015517e+01 8.333400e-01
# 485 ENSG00000049249 OK     prep_batchprep_batch_2  1.521366e-01 2.796150e-02
# 486 ENSG00000116288 OK     (Intercept)             1.569867e+00 4.269091e-03
# 487 ENSG00000116288 OK     gRNA_group             -2.034713e-02 2.524741e-02
# 488 ENSG00000116288 OK     guide_count            -2.648644e-03 8.881516e-05
# 489 ENSG00000116288 OK     percent.mito            1.024915e+01 7.446432e-02
# 490 ENSG00000116288 OK     prep_batchprep_batch_2  1.048933e-01 2.661210e-03
# 491 ENSG00000116285 OK     (Intercept)            -2.207554e+00 3.548351e-02
# 492 ENSG00000116285 OK     gRNA_group             -5.187443e-01 2.583056e-01
# 493 ENSG00000116285 OK     guide_count            -1.793296e-03 7.692576e-04
# 494 ENSG00000116285 OK     percent.mito           -1.555488e+01 6.666009e-01
# 495 ENSG00000116285 OK     prep_batchprep_batch_2  1.947013e-01 2.312359e-02
# 496 ENSG00000142599 OK     (Intercept)            -1.541760e+00 1.474325e-02
# 497 ENSG00000142599 OK     gRNA_group             -1.125386e-01 9.025170e-02
# 498 ENSG00000142599 OK     guide_count            -3.210319e-04 3.039532e-04
# 499 ENSG00000142599 OK     percent.mito            5.577083e+00 2.550158e-01
# 500 ENSG00000142599 OK     prep_batchprep_batch_2  1.095024e-01 9.143885e-03
#     test_val      p_value       normalized_effect q_value
# 1    -76.27885526  0.000000e+00  0.000000e+00      0.000000e+00
# 2      0.28564609  7.751492e-01  7.142159e-02      1.000000e+00
# 3     -0.40666317  6.842554e-01 -3.702237e-04      1.000000e+00
# 4     11.84589335  2.259971e-32  1.605482e+01      8.361894e-31
# 5      1.07359778  2.830030e-01  2.963068e-02      1.000000e+00
# 6   -110.07252209  0.000000e+00  0.000000e+00      0.000000e+00
# 7     -0.63729420  5.239332e-01 -1.258034e-01      1.000000e+00
# 8      8.41879008  3.803923e-17  5.637260e-03      2.929021e-15
# 9     27.62357559 5.798296e-168  2.111604e+01     3.305029e-166
# 10    -1.02800240  3.039487e-01 -2.117832e-02      1.000000e+00
# 11   -54.48297722  0.000000e+00  0.000000e+00      0.000000e+00
# 12    -0.84967572  3.955054e-01 -7.461628e-02      1.000000e+00
# 13    -4.74270166  2.108867e-06 -1.439312e-03      1.328586e-04
# 14     9.81208795  9.988015e-23  2.528726e+00      3.296045e-21
# 15     1.67740494  9.346332e-02  1.529825e-02      1.000000e+00
# 16   -74.88169384  0.000000e+00  0.000000e+00      0.000000e+00
# 17    -0.18877733  8.502673e-01 -5.721547e-02      1.000000e+00
# 18    -2.86994786  4.105395e-03 -3.023916e-03      1.847428e-01
# 19     6.94425660  3.804584e-12  8.561320e+00      9.131002e-11
# 20    -0.76020585  4.471315e-01 -2.375235e-02      1.000000e+00
# 21   -94.33133704  0.000000e+00  0.000000e+00      0.000000e+00
# 22    -0.67222013  5.014436e-01 -1.616454e-01      1.000000e+00
# 23     2.97749419  2.906152e-03  2.416201e-03      1.365891e-01
# 24     9.72176609  2.435205e-22  8.272608e+00      7.792658e-21
# 25     4.09327686  4.253194e-05  1.019958e-01      2.679512e-03
# 26   -61.17109118  0.000000e+00  0.000000e+00      0.000000e+00
# 27     0.78669399  4.314610e-01  2.518493e-01      1.000000e+00
# 28    -0.05555193  9.556988e-01 -6.602708e-05      1.000000e+00
# 29    -3.06409703  2.183281e-03 -1.093669e+00      3.056593e-02
# 30     8.28028097  1.228850e-16  3.238686e-01      9.830799e-15
# ⋮   ⋮             ⋮             ⋮                 ⋮
# 471 -1.160113e+02  0.000000e+00  0.000000e+00      0.000000e+00
# 472 -8.885602e-03  9.929104e-01 -1.071854e-03      1.000000e+00
# 473  1.353067e-02  9.892044e-01  5.761327e-06      1.000000e+00
# 474  3.320996e+01 7.732228e-242  1.245675e+01     4.716659e-240
# 475  1.673065e+01  7.837326e-63  2.154942e-01      7.288713e-61
# 476 -7.300070e+01  0.000000e+00  0.000000e+00      0.000000e+00
# 477 -4.248382e-01  6.709547e-01 -1.052847e-01      1.000000e+00
# 478 -1.130358e+00  2.583255e-01 -9.670267e-04      1.000000e+00
# 479  1.383142e+01  1.647396e-43  2.080507e+01      6.589583e-42
# 480  1.620393e-01  8.712749e-01  4.153168e-03      1.000000e+00
# 481 -4.459291e+01  0.000000e+00  0.000000e+00      0.000000e+00
# 482 -1.753229e+00  7.956271e-02 -7.134159e-01      1.000000e+00
# 483 -1.567286e+00  1.170478e-01 -1.967056e-03      1.000000e+00
# 484 -3.618592e+01 1.013859e-286 -4.015853e+00     6.488695e-285
# 485  5.440930e+00  5.300309e-08  2.068451e-01      3.763220e-06
# 486  3.677285e+02  0.000000e+00  0.000000e+00      0.000000e+00
# 487 -8.059094e-01  4.202951e-01 -2.929312e-02      1.000000e+00
# 488 -2.982198e+01 2.027412e-195 -3.813240e-03     2.007138e-193
# 489  1.376385e+02  0.000000e+00  1.478341e+01      0.000000e+00
# 490  3.941563e+01  0.000000e+00  1.510307e-01      0.000000e+00
# 491 -6.221353e+01  0.000000e+00  0.000000e+00      0.000000e+00
# 492 -2.008258e+00  4.461589e-02 -6.688591e-01      1.000000e+00
# 493 -2.331203e+00  1.974263e-02 -2.371348e-03      8.291906e-01
# 494 -2.333462e+01 1.974708e-120 -3.584590e+00     1.026848e-118
# 495  8.420027e+00  3.763985e-17  2.594606e-01      3.086468e-15
# 496 -1.045740e+02  0.000000e+00  0.000000e+00      0.000000e+00
# 497 -1.246941e+00  2.124191e-01 -1.547075e-01      1.000000e+00
# 498 -1.056189e+00  2.908821e-01 -4.424720e-04      1.000000e+00
# 499  2.186956e+01 5.064755e-106  7.980398e+00     2.532378e-104
# 500  1.197548e+01  4.776704e-33  1.512830e-01      4.155732e-31

# %% [markdown]
# It takes 2.53 seconds to test a relationship pair between a set of variables and a gene, on average.
#
# This means that it will take **6.9 years** to complete the test of 85,929,170 pairs of interactions between 6,542 gRNA groups and 13,135 genes ! ! !
#
# In the paper, Gasperini et al. measured the relationship between each gRNA group and surrounding 1 Mbp genes, a total of 629,515 pairs. They also used negbinomial.size family to increase speed by reducing accuracy.
#
# Now, let's move to python.

# %% [markdown]
# ## Statsmodels

# %% [markdown]
# Scpy is deeply inspired by statsmodels [4] and relies on it to solve optimizations.
#
# We first show how to use statsmodels for differential expression analysis.

# %%
import os, sys
from tqdm import tqdm
import time

import pandas as pd
import numpy as np

from scipy import stats

import statsmodels as sm
import statsmodels.api

# %%
base = '/home/jjpeng/data/yxlong/CRISPR/source/30849375/GEO/'

# %% [markdown]
# ### load featureData & phenoData

# %%
grnas = pd.read_csv(base + 'GSE120861_grna_groups.at_scale.txt.gz', sep = '\t', header=None)[1]
cells = pd.read_csv(base + 'GSE120861_at_scale_screen.cells.txt.gz', sep = '\t', header=None)[0]
genes = pd.read_csv(base + 'GSE120861_at_scale_screen.genes.txt.gz', sep = '\t', header=None)[0]

# %%
phenoData = pd.read_csv(base + 'GSE120861_at_scale_screen.phenoData.txt.gz', sep=' ', header=None, usecols=[0,1,2,5,7,8,9,10,14,17])
phenoData.columns = ['sample','cell','total_umis','gRNA_groups','read_count','umi_count','proportion','guide_count','prep_batch','percent.mito']
phenoData.set_index('cell', inplace=True)

phenoData['guide_count'].fillna(0, inplace=True)
phenoData['size_factor'] = phenoData['total_umis'] / np.exp(np.mean(np.log(phenoData['total_umis'])))
phenoData['prep_batch'] = phenoData.eval('prep_batch != "prep_batch_1"').astype(int)

phenoData
# Out:
#                                          sample  total_umis  \
# cell
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  1A_1_SI-GA-E2     17572.0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  1A_1_SI-GA-E2      8923.0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  1A_1_SI-GA-E2     14637.0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  1A_1_SI-GA-E2     22798.0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2  1A_1_SI-GA-E2     10136.0
# ...                                         ...         ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9  2B_8_SI-GA-H9     17938.0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9  2B_8_SI-GA-H9     16543.0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9  2B_8_SI-GA-H9     15009.0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9  2B_8_SI-GA-H9      5149.0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9  2B_8_SI-GA-H9      9503.0
#
#                                                                         gRNA_groups  \
# cell
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2  chr10.185_top_two_chr10.484_top_two_chr11.4167...
# ...                                                                             ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9  BRIX1_TSS_chr10.2059_top_two_chr10.350_top_two...
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9  chr10.221_top_two_chr11.3853_top_two_chr11.498...
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9    chr12.3400_top_two_chr4.1281_second_two_ID3_TSS
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                                  chr7.1014_top_two
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9  chr11.2790_top_two_chr12.306_top_two_chr12.474...
#
#                                   read_count  umi_count  proportion  \
# cell
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2     14135.0      964.0    0.969819
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2      4329.0      293.0    0.844380
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     12362.0      884.0    0.950538
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2      7459.0      544.0    0.939551
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     14831.0     1054.0    0.959927
# ...                                      ...        ...         ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9      4570.0      394.0    0.856522
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9      4311.0      387.0    0.861915
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9       669.0       57.0    0.876923
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9        77.0        7.0    0.086420
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9      4630.0      410.0    0.813492
#
#                                   guide_count  prep_batch  percent.mito  \
# cell
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2         67.0           0      0.058787
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2         26.0           0      0.036087
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2         61.0           0      0.069823
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2         39.0           0      0.026187
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2         37.0           0      0.007991
# ...                                       ...         ...           ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9         31.0           1      0.060598
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9         33.0           1      0.057789
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9          3.0           1      0.049037
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9          1.0           1      0.000971
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9         35.0           1      0.028623
#
#                                   size_factor
# cell
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2     1.084235
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2     0.550571
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     0.903138
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2     1.406692
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     0.625416
# ...                                       ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9     1.106818
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9     1.020743
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9     0.926092
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9     0.317706
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9     0.586358
#
# [207324 rows x 10 columns]

# %% [markdown]
# ### prepare & load expression data

# %%
if not os.path.exists(base + 'at_scale.exprs.npy'):

    mtx = pd.read_csv(base + 'GSE120861_at_scale_screen.exprs.mtx.gz', sep = ' ', header=None, skiprows=2, compression=None)
    coo = sp.sparse.coo_matrix((mtx[2], (mtx[0] - 1, mtx[1] - 1)), shape=(genes.shape[0], cells.shape[0]), dtype=np.int16)
    np.save(base + 'at_scale.exprs.npy', coo)
    
else:

    coo = np.load(base + 'at_scale.exprs.npy', allow_pickle=True).item()

# %%
exprs = pd.DataFrame.sparse.from_spmatrix(coo.T, index=cells, columns=genes)

exprs
# Out:
# 0                                 ENSG00000238009  ENSG00000237683  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                1
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                0                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                1
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                0
#
# 0                                 ENSG00000228463  ENSG00000237094  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                1                0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                1                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                1                1
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                1                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                2                0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                2                0
#
# 0                                 ENSG00000235373  ENSG00000228327  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                1                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                0
#
# 0                                 ENSG00000237491  ENSG00000225880  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                0                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                1                0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                0
#
# 0                                 ENSG00000230368  ENSG00000188976  ...  \
# 0                                                                   ...
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                0  ...
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0  ...
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                0                3  ...
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                1  ...
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0  ...
# ...                                           ...              ...  ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                1  ...
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                3  ...
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                4  ...
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                1  ...
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                2  ...
#
# 0                                 ENSG00000198886  ENSG00000198786  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2              115               20
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2               45               17
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2              156               20
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2               66               24
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                8                4
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9              119               30
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9              113               32
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9               93               21
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                1                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9               33               13
#
# 0                                 ENSG00000198695  ENSG00000198727  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                5               90
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                1               36
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                4               80
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                1               21
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0               15
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                6               97
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9               13               60
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                2               68
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0               27
#
# 0                                 ENSG00000215750  ENSG00000215689  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                1                0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                0                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                0
#
# 0                                 ENSG00000215781  ENSG00000220023  \
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                1
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                1
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                0                1
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                2                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                1
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                1                1
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                1                1
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                1
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                1
#
# 0                                 ENSG00000215615  ENSG00000215699
# 0
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                0                0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                0                0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                1                0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                0                0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                0                0
# ...                                           ...              ...
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                0                1
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                0                0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                0                0
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                0                0
#
# [207324 rows x 13135 columns]

# %% [markdown]
# ### choose bassik_mch, a non-targeting control gRNA group and 100 genes as an example

# %%
phenoData['gRNA_group'] = phenoData['gRNA_groups'].str.contains('bassik_mch', na=False).astype(int)

subset = exprs[exprs.columns[:100]]

# %% [markdown]
# ### differential expression analysis

# %%
# x

x = phenoData[['gRNA_group','guide_count','percent.mito','prep_batch']].values
x = sm.api.add_constant(x, prepend=False)

xname = ['gRNA_group','guide_count','percent.mito','prep_batch','intercept']

# y

size_factor = phenoData['size_factor'].values

Y = np.round(subset.values.T / size_factor)

# fit

summaries = list()
for gene, y in zip(tqdm(subset.columns), Y):
    
    model = sm.discrete.discrete_model.NegativeBinomial(y, x, loglike_method='geometric')
    res = model.fit(disp=False, warn_convergence=False)
    summary = res.summary2(xname=xname).tables[1]
    
    summary['term'] = summary.index
    summary.index = [gene] * summary.shape[0]
    summaries.append(summary)
    
summaries = pd.concat(summaries, axis=0)

summaries
# Out:
# 100%|██████████| 100/100 [02:16<00:00,  1.36s/it]
#                      Coef.  Std.Err.           z          P>|z|    [0.025  \
# ENSG00000238009   0.121739  0.291886    0.417079   6.766204e-01 -0.450346
# ENSG00000238009  -0.000337  0.001084   -0.310907   7.558716e-01 -0.002462
# ENSG00000238009  11.765150  0.905019   12.999893   1.225147e-38  9.991345
# ENSG00000238009   0.041200  0.032899    1.252321   2.104528e-01 -0.023281
# ENSG00000238009  -4.495644  0.053886  -83.428977   0.000000e+00 -4.601258
# ...                    ...       ...         ...            ...       ...
# ENSG00000142599  -0.111505  0.093053   -1.198287   2.308052e-01 -0.293886
# ENSG00000142599  -0.000184  0.000310   -0.593772   5.526647e-01 -0.000793
# ENSG00000142599   5.626938  0.263224   21.376973  2.188725e-101  5.111028
# ENSG00000142599   0.109529  0.009431   11.614294   3.486571e-31  0.091046
# ENSG00000142599  -1.548903  0.015096 -102.605106   0.000000e+00 -1.578490
#
#                     0.975]          term
# ENSG00000238009   0.693825    gRNA_group
# ENSG00000238009   0.001788   guide_count
# ENSG00000238009  13.538954  percent.mito
# ENSG00000238009   0.105681    prep_batch
# ENSG00000238009  -4.390030     intercept
# ...                    ...           ...
# ENSG00000142599   0.070877    gRNA_group
# ENSG00000142599   0.000424   guide_count
# ENSG00000142599   6.142848  percent.mito
# ENSG00000142599   0.128013    prep_batch
# ENSG00000142599  -1.519316     intercept
#
# [500 rows x 7 columns]

# %% [markdown]
# ### compare with monocle3 results

# %%
# load monocle3 results
df = pd.read_csv('bassik_mch-100.csv', index_col=0)

# transform into wide-style table

monocle3_results = df.query('term == "gRNA_group"')[['term','estimate','p_value']]
for i in ['(Intercept)','guide_count','percent.mito','prep_batchprep_batch_2']:
    monocle3_results[i] = df.query('term == "%s"' % i)['estimate']
    
results = summaries.query('term == "gRNA_group"')[['term','Coef.','P>|z|']]
for i in ['intercept','guide_count','percent.mito','prep_batch']:
    results[i] = summaries.query('term == "%s"' % i)['Coef.']
    
# Pearson correlation test

print('Spearman correlation of')
print('effect size', *stats.spearmanr(results['Coef.'], monocle3_results['estimate']))
print('intercept', *stats.spearmanr(results['intercept'], monocle3_results['(Intercept)']))
print('p-value', *stats.spearmanr(results['P>|z|'], monocle3_results['p_value']))
# Out:
# Spearman correlation of
# effect size 0.9972397239723971 1.7145424785108527e-112
# intercept 0.9998799879987997 3.439317197857124e-179
# p-value 0.9475907590759075 2.314617210933284e-50

# %% [markdown]
# Statsmodels got highly consistent results with monocle3, but it was still too slow.
#
# Now, let's try scpy.

# %% [markdown]
# ## Scpy

# %%
import torch
import scpy

# %% [markdown]
# ### differential expression analysis

# %% [markdown]
# Scpy uses an API similar to statsmodels when fitting a single pair.

# %%
summaries = list()
for gene, y in zip(tqdm(subset.columns), Y):
    
    summary = scpy.fit(x, y, 'negative_binomial', device='cpu', xname=xname)
    
    summary['term'] = summary.index
    summary.index = [gene] * summary.shape[0]
    summaries.append(summary)
    
summaries = pd.concat(summaries, axis=0)

summaries
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.10it/s]
#                      Coef.  Std.Err.           z          P>|z|          term
# ENSG00000238009   0.118145  0.292382    0.404078   6.861557e-01    gRNA_group
# ENSG00000238009  -0.000333  0.001084   -0.306772   7.590171e-01   guide_count
# ENSG00000238009  11.762953  0.905033   12.997268   1.312820e-38  percent.mito
# ENSG00000238009   0.041310  0.032900    1.255632   2.092508e-01    prep_batch
# ENSG00000238009  -4.495757  0.053887  -83.429970   0.000000e+00     intercept
# ...                    ...       ...         ...            ...           ...
# ENSG00000142599  -0.113176  0.093100   -1.215645   2.241214e-01    gRNA_group
# ENSG00000142599  -0.000190  0.000311   -0.611838   5.406457e-01   guide_count
# ENSG00000142599   5.665720  0.263223   21.524412  1.192395e-102  percent.mito
# ENSG00000142599   0.109481  0.009431   11.609066   3.789701e-31    prep_batch
# ENSG00000142599  -1.550258  0.015097 -102.684689   0.000000e+00     intercept
#
# [500 rows x 5 columns]

# %%
results = summaries.query('term == "gRNA_group"')[['term','Coef.','P>|z|']]
for i in ['intercept','guide_count','percent.mito','prep_batch']:
    results[i] = summaries.query('term == "%s"' % i)['Coef.']
    
# Pearson correlation test

print('Spearman correlation of')
print('effect size', *stats.spearmanr(results['Coef.'], monocle3_results['estimate']))
print('intercept', *stats.spearmanr(results['intercept'], monocle3_results['(Intercept)']))
print('p-value', *stats.spearmanr(results['P>|z|'], monocle3_results['p_value']))
# Out:
# Spearman correlation of
# effect size 0.9985718571857185 1.678441941676762e-126
# intercept 0.9998919891989198 1.9700524468233987e-181
# p-value 0.9574557455745574 1.071068835741778e-54

# %% [markdown]
# Wow, it's **20X faster** and as accurate as monocle3.

# %% [markdown]
# ### differential expression analysis in batch

# %% [markdown]
# Scpy provides a more convenient and efficient API for fitting multiple sets of independent variables and dependent variables at the same time.

# %%
summaries = scpy.fit_batch([x], Y, 'negative_binomial', device='cpu', xnames=[('bassik_mch', xname)], yname=subset.columns)

summaries
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 16.95it/s]
#                                              Coef.  Std.Err.           z  \
# group      term         target
# bassik_mch gRNA_group   ENSG00000238009   0.118145  0.292382    0.404078
#            guide_count  ENSG00000238009  -0.000333  0.001084   -0.306772
#            percent.mito ENSG00000238009  11.762953  0.905033   12.997268
#            prep_batch   ENSG00000238009   0.041310  0.032900    1.255632
#            intercept    ENSG00000238009  -4.495757  0.053887  -83.429970
# ...                                            ...       ...         ...
#            gRNA_group   ENSG00000142599  -0.113176  0.093100   -1.215645
#            guide_count  ENSG00000142599  -0.000190  0.000311   -0.611838
#            percent.mito ENSG00000142599   5.665720  0.263223   21.524412
#            prep_batch   ENSG00000142599   0.109481  0.009431   11.609066
#            intercept    ENSG00000142599  -1.550258  0.015097 -102.684689
#
#                                                  P>|z|
# group      term         target
# bassik_mch gRNA_group   ENSG00000238009   6.861557e-01
#            guide_count  ENSG00000238009   7.590171e-01
#            percent.mito ENSG00000238009   1.312820e-38
#            prep_batch   ENSG00000238009   2.092508e-01
#            intercept    ENSG00000238009   0.000000e+00
# ...                                                ...
#            gRNA_group   ENSG00000142599   2.241214e-01
#            guide_count  ENSG00000142599   5.406457e-01
#            percent.mito ENSG00000142599  1.192395e-102
#            prep_batch   ENSG00000142599   3.789701e-31
#            intercept    ENSG00000142599   0.000000e+00
#
# [500 rows x 4 columns]

# %% [markdown]
# If you have a GPU, scpy can run faster.

# %%
summaries = scpy.fit_batch([x], Y, 'negative_binomial', device=0, xnames=[('bassik_mch', xname)], yname=subset.columns)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 54.09it/s]

# %% [markdown]
# Sometimes, the size of the dependent variable is large, or it takes a long time for preprocessing.
#
# For example, the expression matrix in the sample occupies 6.5 GB of memory when stored in a sparse form. If it is converted to dense form all at once for calculation, it will occupy at least 30GB of memory.
#
# Scpy provides lazy data loader to solve this problem.

# %%
loader = lambda i: np.round(subset[subset.columns[i]].values.T / size_factor)
Ys = scpy.dataloader(loader, len(subset.columns), num_workers=2)

summaries = scpy.fit_batch([x], Ys, 'negative_binomial', device=0, xnames=[('bassik_mch', xname)], yname=subset.columns)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 47.75it/s]

# %% [markdown]
# So far, we have been able to obtain **100X faster** than the R package.
#
# Can it be faster?

# %% [markdown]
# ### differential expression analysis in parallel

# %% [markdown]
# In order to maximize the performance of scpy and the device, you can use the parallel API.
#
# Parallel scpy only provides a command line API based on multiprocessing, and requires a python script to export args.
#
# We provide a sample script, *demo.py* .

# %% [markdown]
# ```python
# # prepare
#
# ## x
#
# # select 2 gRNA groups targeting non-coding regions, 2 positiv control gRNA groups and 3 non-targeting control gRNA
# gRNA_groups = ['chr1.8492','chrX.952','CERS2_TSS','GATA2_TSS','bassik_mch','random_1','scrambled_1']
#
# X, xnames = list(), list()
#
# for gRNA_group in gRNA_groups:
#
#   geno = phenoData['gRNA_groups'].str.contains(gRNA_group, na=False) # get genotypes
#
#   x = geno.astype(int).values.reshape((-1, 1)) # use genotype as x
#   cov = phenoData[['guide_count','percent.mito','prep_batch']].values # covariants
#   c = np.ones((x.shape[0], 1)) # constraint
#
#   X.append(np.concatenate([x, cov, c], axis=1))
#   xnames.append((gRNA_group, ['gRNA_group', 'guide_count', 'percent.mito', 'prep_batch', 'intercept']))
#
# ## y
#
# size_factor = phenoData['Size_Factor'].values # load size factor calculate by monocle
#
# loader = lambda i: np.round(exprs[exprs.columns[i]].values.T / size_factor)
#
#
# # export
#
# args = {
#   'X': X,
#   'Y': {'data': loader, 'length': exprs.shape[1]},
#   'family': 'negative_binomial',
#   'xnames': xnames,
#   'yname': exprs.columns
# }
# ```

# %% [markdown]
# If I have 8 GPUs, I can run the following commands in the console:

# %% [markdown]
# ```bash
# python -m scpy demo.py demo.csv -d 0,1,2,3,4,5,6,7 --disp=True --low_memory=True
# ```

# %% [markdown]
# ```
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:31<00:00,  7.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:31<00:00,  7.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:32<00:00,  7.72it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:33<00:00,  7.69it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:32<00:00,  7.71it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1641/1641 [03:33<00:00,  7.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:33<00:00,  7.69it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1642/1642 [03:34<00:00,  7.66it/s]
# 221.72746539115906
#                                                     Coef.  Std.Err.          z         P>|z|
# group             term         target
# chr1.8492_top_two gRNA_group   ENSG00000238009   0.202458  0.196002   1.032938  3.016340e-01
#                   guide_count  ENSG00000238009   0.008593  0.001002   8.579515  9.591534e-18
#                   percent.mito ENSG00000238009  17.562862  0.873383  20.109011  7.500587e-90
#                   prep_batch   ENSG00000238009  -0.019360  0.031808  -0.608657  5.427524e-01
#                   intercept    ENSG00000238009  -4.929867  0.053910 -91.446486  0.000000e+00
# ...                                                   ...       ...        ...           ...
# bassik_mch        gRNA_group   ENSG00000215699   0.388362  0.320037   1.213490  2.249438e-01
#                   guide_count  ENSG00000215699   0.006148  0.001344   4.574964  4.765763e-06
#                   percent.mito ENSG00000215699  13.970382  1.161668  12.026145  2.656786e-33
#                   prep_batch   ENSG00000215699   0.043774  0.042161   1.038266  2.991475e-01
#                   intercept    ENSG00000215699  -5.298037  0.070448 -75.204969  0.000000e+00
#
# [459725 rows x 4 columns]
# ```

# %% [markdown]
# **OMG, we are now 1000X faster ! ! !**
#
# Let us check whether the results of scpy are consistent with those provided by Gasperini et al.

# %%
# load results from the paper

paper = pd.read_csv(base + 'GSE120861_all_deg_results.at_scale.txt.gz', sep='\t', index_col='pairs4merge')

paper
# Out:
# /home/jjpeng/data/.conda/envs/torch-latest/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                 beta  intercept  \
# pairs4merge
# ACTB_TSS:ENSG00000008256   -0.114784  -3.432141
# ACTB_TSS:ENSG00000011275   -0.042450  -1.464958
# ACTB_TSS:ENSG00000075618    0.034076   0.392365
# ACTB_TSS:ENSG00000075624   -0.437939   2.898258
# ACTB_TSS:ENSG00000086232   -0.010209   1.154783
# ...                              ...        ...
# ZRANB2_TSS:ENSG00000116754 -0.016496   0.174595
# ZRANB2_TSS:ENSG00000116761  0.022505  -1.795345
# ZRANB2_TSS:ENSG00000118454 -0.039160  -2.665878
# ZRANB2_TSS:ENSG00000132485 -0.581223  -0.493145
# ZRANB2_TSS:ENSG00000197568  0.052511  -1.413776
#
#                             fold_change.transcript_remaining     pvalue.raw  \
# pairs4merge
# ACTB_TSS:ENSG00000008256                            0.891559   2.746239e-01
# ACTB_TSS:ENSG00000011275                            0.958438   2.771529e-01
# ACTB_TSS:ENSG00000075618                            1.034664   1.425945e-01
# ACTB_TSS:ENSG00000075624                            0.645365  7.463645e-115
# ACTB_TSS:ENSG00000086232                            0.989843   6.253678e-01
# ...                                                      ...            ...
# ZRANB2_TSS:ENSG00000116754                          0.983639   4.979588e-01
# ZRANB2_TSS:ENSG00000116761                          1.022760   7.781657e-01
# ZRANB2_TSS:ENSG00000118454                          0.961597   6.191715e-01
# ZRANB2_TSS:ENSG00000132485                          0.559214   2.525892e-65
# ZRANB2_TSS:ENSG00000197568                          1.053914   3.484490e-01
#
#                            pvalue.empirical pvalue.empirical.adjusted  \
# pairs4merge
# ACTB_TSS:ENSG00000008256        0.261969034         0.831159512731444
# ACTB_TSS:ENSG00000011275        0.264361067         0.831814624048016
# ACTB_TSS:ENSG00000075618     not_applicable            not_applicable
# ACTB_TSS:ENSG00000075624          3.941e-06      0.000407265538461538
# ACTB_TSS:ENSG00000086232        0.611785198         0.947813794532952
# ...                                     ...                       ...
# ZRANB2_TSS:ENSG00000116754      0.482804551         0.916882597262894
# ZRANB2_TSS:ENSG00000116761   not_applicable            not_applicable
# ZRANB2_TSS:ENSG00000118454      0.605440595         0.946588425199907
# ZRANB2_TSS:ENSG00000132485        3.941e-06      0.000407265538461538
# ZRANB2_TSS:ENSG00000197568   not_applicable            not_applicable
#
#                                        ENSG gene_short_name  gRNA_group  \
# pairs4merge
# ACTB_TSS:ENSG00000008256    ENSG00000008256           CYTH3    ACTB_TSS
# ACTB_TSS:ENSG00000011275    ENSG00000011275          RNF216    ACTB_TSS
# ACTB_TSS:ENSG00000075618    ENSG00000075618           FSCN1    ACTB_TSS
# ACTB_TSS:ENSG00000075624    ENSG00000075624            ACTB    ACTB_TSS
# ACTB_TSS:ENSG00000086232    ENSG00000086232         EIF2AK1    ACTB_TSS
# ...                                     ...             ...         ...
# ZRANB2_TSS:ENSG00000116754  ENSG00000116754          SRSF11  ZRANB2_TSS
# ZRANB2_TSS:ENSG00000116761  ENSG00000116761             CTH  ZRANB2_TSS
# ZRANB2_TSS:ENSG00000118454  ENSG00000118454        ANKRD13C  ZRANB2_TSS
# ZRANB2_TSS:ENSG00000132485  ENSG00000132485          ZRANB2  ZRANB2_TSS
# ZRANB2_TSS:ENSG00000197568  ENSG00000197568           HHLA3  ZRANB2_TSS
#
#                            quality_rank_grna target_site.chr  \
# pairs4merge
# ACTB_TSS:ENSG00000008256             control            chr7
# ACTB_TSS:ENSG00000011275             control            chr7
# ACTB_TSS:ENSG00000075618             control            chr7
# ACTB_TSS:ENSG00000075624             control            chr7
# ACTB_TSS:ENSG00000086232             control            chr7
# ...                                      ...             ...
# ZRANB2_TSS:ENSG00000116754           control            chr1
# ZRANB2_TSS:ENSG00000116761           control            chr1
# ZRANB2_TSS:ENSG00000118454           control            chr1
# ZRANB2_TSS:ENSG00000132485           control            chr1
# ZRANB2_TSS:ENSG00000197568           control            chr1
#
#                            target_site.start target_site.stop target_gene.chr  \
# pairs4merge
# ACTB_TSS:ENSG00000008256             5570339          5570340            chr7
# ACTB_TSS:ENSG00000011275             5570339          5570340            chr7
# ACTB_TSS:ENSG00000075618             5570339          5570340            chr7
# ACTB_TSS:ENSG00000075624             5570339          5570340            chr7
# ACTB_TSS:ENSG00000086232             5570339          5570340            chr7
# ...                                      ...              ...             ...
# ZRANB2_TSS:ENSG00000116754          71546971         71546972            chr1
# ZRANB2_TSS:ENSG00000116761          71546971         71546972            chr1
# ZRANB2_TSS:ENSG00000118454          71546971         71546972            chr1
# ZRANB2_TSS:ENSG00000132485          71546971         71546972            chr1
# ZRANB2_TSS:ENSG00000197568          71546971         71546972            chr1
#
#                             target_gene.start  target_gene.stop strand  \
# pairs4merge
# ACTB_TSS:ENSG00000008256              6312274           6312275      -
# ACTB_TSS:ENSG00000011275              5821369           5821370      -
# ACTB_TSS:ENSG00000075618              5632454           5632455      +
# ACTB_TSS:ENSG00000075624              5570339           5570340      -
# ACTB_TSS:ENSG00000086232              6098860           6098861      -
# ...                                       ...               ...    ...
# ZRANB2_TSS:ENSG00000116754           70671365          70671366      +
# ZRANB2_TSS:ENSG00000116761           70876901          70876902      +
# ZRANB2_TSS:ENSG00000118454           70820416          70820417      -
# ZRANB2_TSS:ENSG00000132485           71546971          71546972      -
# ZRANB2_TSS:ENSG00000197568           70820488          70820489      +
#
#                            site_type  outlier_gene
# pairs4merge
# ACTB_TSS:ENSG00000008256         TSS         False
# ACTB_TSS:ENSG00000011275         TSS         False
# ACTB_TSS:ENSG00000075618         TSS         False
# ACTB_TSS:ENSG00000075624     selfTSS         False
# ACTB_TSS:ENSG00000086232         TSS         False
# ...                              ...           ...
# ZRANB2_TSS:ENSG00000116754       TSS         False
# ZRANB2_TSS:ENSG00000116761       TSS         False
# ZRANB2_TSS:ENSG00000118454       TSS         False
# ZRANB2_TSS:ENSG00000132485   selfTSS         False
# ZRANB2_TSS:ENSG00000197568       TSS         False
#
# [629515 rows x 19 columns]

# %%
df = pd.read_csv('demo.csv')

for gRNA_group, g in df.groupby('group'):
    
    g.set_index('target', inplace=True)
    
    results = g.query('term == "gRNA_group"')[['term','Coef.','P>|z|']]
    results['intercept'] = g.query('term == "intercept"')['Coef.']
    for i in ['guide_count','percent.mito','prep_batch']:
        results[i] = g.query('term == "%s"' % i)['Coef.']
        
    paper_results = paper.query('gRNA_group == "%s"' % gRNA_group)
    paper_results.set_index('ENSG', inplace=True)
    paper_results = paper_results.loc[paper_results.index.intersection(results.index)]
    
    results = results.loc[paper_results.index]
    
    print('\n', gRNA_group, '\n')

    print('effect size', *stats.spearmanr(results['Coef.'], paper_results['beta']))
    print('intercept', *stats.spearmanr(results['intercept'], paper_results['intercept']))
    print('p-value', *stats.spearmanr(results['P>|z|'], paper_results['pvalue.raw']))
# Out:
#  CERS2_TSS
#
# effect size 0.9823353050806256 9.800019237294788e-31
# intercept 0.998541447208492 2.4632354748867975e-52
# p-value 0.95753990762499 3.235472204989662e-23
#
#  GATA2_TSS
#
# effect size 0.9964912280701754 9.285165080058482e-20
# intercept 0.9982456140350877 2.579846712328762e-22
# p-value 0.9210526315789472 2.2361332893791837e-08
#
#  bassik_mch
#
# effect size 0.9879195444074778 0.0
# intercept 0.9994431151886197 0.0
# p-value 0.9590769458326537 0.0
#
#  chr1.8492_second_two
#
# effect size 0.9931934203062961 5.631027405850918e-39
# intercept 0.9987035086297708 2.339336383494484e-53
# p-value 0.9530021878291874 2.3641247234831865e-22
#
#  chr1.8492_top_two
#
# effect size 0.9701806984847258 3.095784714315404e-26
# intercept 0.9987035086297708 2.339336383494484e-53
# p-value 0.9701806984847258 3.095784714315404e-26
#
#  chrX.952_second_two
#
# effect size 0.9952346041055717 6.809255742590661e-32
# intercept 0.9978005865102637 6.361252877369035e-37
# p-value 0.9754398826979471 2.8726637865941426e-21
#
#  chrX.952_top_two
#
# effect size 0.9882697947214076 4.800382460030913e-26
# intercept 0.9978005865102637 6.361252877369035e-37
# p-value 0.9772727272727272 9.084840026751097e-22

# %% [markdown]
# ## Reference

# %% [markdown]
# [1] Gasperini M, Hill AJ, McFaline-Figueroa JL, Martin B et al. A Genome-wide Framework for Mapping Gene Regulation via Cellular Genetic Screens. Cell 2019 Jan 10;176(1-2):377-390.e19. PMID: 30612741
#
# [2] Qiu, X. et. al. Reversed graph embedding resolves complex single-cell trajectories. Nat. Methods 14, 979–982 (2017). https://doi.org/10.1038/nmeth.4402
#
# [3] Cao, J. et. al. The single-cell transcriptional landscape of mammalian organogenesis. Nature 566, 496–502 (2019). https://doi.org/10.1038/s41586-019-0969-x
#
# [4] Seabold, Skipper, and Josef Perktold. “statsmodels: Econometric and statistical modeling with python.” Proceedings of the 9th Python in Science Conference. 2010.
